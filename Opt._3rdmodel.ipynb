# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import os
from tensorflow.keras.callbacks import ModelCheckpoint

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("./Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df=application_df.drop(columns=["EIN", "NAME"])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_column= application_df["APPLICATION_TYPE"].value_counts()
application_column
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace= application_column[application_column < 500].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_column=application_df["CLASSIFICATION"].value_counts()
class_column.head()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace=class_column[class_column < 800].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Generating categorical variable list
application_ctg= application_df.dtypes[application_df.dtypes =="object"].index.tolist()
application_df[application_ctg].nunique()
# Out:
# APPLICATION_TYPE          9
# AFFILIATION               6
# CLASSIFICATION            6
# USE_CASE                  5
# ORGANIZATION              4
# INCOME_AMT                9
# SPECIAL_CONSIDERATIONS    2
# dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
new_app_df = pd.get_dummies(data=application_df, columns=['APPLICATION_TYPE','INCOME_AMT', 'AFFILIATION','CLASSIFICATION','USE_CASE','ORGANIZATION','SPECIAL_CONSIDERATIONS'])
new_app_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        USE_CASE_Heathcare  USE_CASE_Other  USE_CASE_Preservation  \
# 0                       0               0                      0
# 1                       0               0                      1
# 2                       0               0                      0
# 3                       0               0                      1
# 4                       1               0                      0
# ...                   ...             ...                    ...
# 34294                   0               0                      0
# 34295                   0               0                      0
# 34296                   0               0                      1
# 34297                   0               0                      0
# 34298                   0               0                      1
#
#        USE_CASE_ProductDev  ORGANIZATION_Association  \
# 0                        1                         1
# 1                        0                         0
# 2                        1                         1
# 3                        0                         0
# 4                        0                         0
# ...                    ...                       ...
# 34294                    1                         1
# 34295                    1                         1
# 34296                    0                         1
# 34297                    1                         1
# 34298                    0                         0
#
#        ORGANIZATION_Co-operative  ORGANIZATION_Corporation  \
# 0                              0                         0
# 1                              1                         0
# 2                              0                         0
# 3                              0                         0
# 4                              0                         0
# ...                          ...                       ...
# 34294                          0                         0
# 34295                          0                         0
# 34296                          0                         0
# 34297                          0                         0
# 34298                          1                         0
#
#        ORGANIZATION_Trust  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                       0                         1                         0
# 1                       0                         1                         0
# 2                       0                         1                         0
# 3                       1                         1                         0
# 4                       1                         1                         0
# ...                   ...                       ...                       ...
# 34294                   0                         1                         0
# 34295                   0                         1                         0
# 34296                   0                         1                         0
# 34297                   0                         1                         0
# 34298                   0                         1                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
y= new_app_df["IS_SUCCESSFUL"].values
X= new_app_df.drop(columns= ["IS_SUCCESSFUL"]).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test= train_test_split(X,y,random_state=30)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
print(len(new_app_df.columns))
# Out:
# 44

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

number_input_features= len(X_train[0])
hidden_layers1= 30
hidden_layers2= 25
hidden_layers3= 20
hidden_layers4= 15
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_layers1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_layers2, input_dim=number_input_features, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_layers3, input_dim=number_input_features, activation="relu"))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_layers4, input_dim=number_input_features, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                1320
#
#  dense_1 (Dense)             (None, 25)                775
#
#  dense_2 (Dense)             (None, 20)                520
#
#  dense_3 (Dense)             (None, 15)                315
#
#  dense_4 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 2,946
# Trainable params: 2,946
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model

os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

nn.compile(loss="binary_crossentropy", optimizer="adam", metrics= ["accuracy"])

# %%
# Train the model
cp_callback= ModelCheckpoint(filepath=checkpoint_path,save_weights_only=True, save_freq=5)

fit_model= nn.fit(X_train_scaled, y_train, epochs=100, verbose=1, callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 3ms/step - loss: 0.5766 - accuracy: 0.7154
# Epoch 2/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5523 - accuracy: 0.7321
# Epoch 3/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5500 - accuracy: 0.7337
# Epoch 4/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5472 - accuracy: 0.7343
# Epoch 5/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5464 - accuracy: 0.7341
# Epoch 6/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5456 - accuracy: 0.7341
# Epoch 7/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5445 - accuracy: 0.7347
# Epoch 8/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5444 - accuracy: 0.7348
# Epoch 9/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5436 - accuracy: 0.7368
# Epoch 10/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5432 - accuracy: 0.7367
# Epoch 11/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5430 - accuracy: 0.7365
# Epoch 12/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5422 - accuracy: 0.7384
# Epoch 13/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5422 - accuracy: 0.7366
# Epoch 14/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5415 - accuracy: 0.7369
# Epoch 15/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5412 - accuracy: 0.7376
# Epoch 16/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5412 - accuracy: 0.7383
# Epoch 17/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5401 - accuracy: 0.7385
# Epoch 18/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5405 - accuracy: 0.7382
# Epoch 19/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5400 - accuracy: 0.7391
# Epoch 20/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5396 - accuracy: 0.7387
# Epoch 21/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5395 - accuracy: 0.7386
# Epoch 22/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5396 - accuracy: 0.7390
# Epoch 23/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5394 - accuracy: 0.7390
# Epoch 24/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5389 - accuracy: 0.7399
# Epoch 25/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5389 - accuracy: 0.7390
# Epoch 26/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5388 - accuracy: 0.7399
# Epoch 27/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5386 - accuracy: 0.7394
# Epoch 28/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5382 - accuracy: 0.7400
# Epoch 29/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5380 - accuracy: 0.7390
# Epoch 30/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5381 - accuracy: 0.7399
# Epoch 31/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5381 - accuracy: 0.7392
# Epoch 32/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5376 - accuracy: 0.7400
# Epoch 33/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5375 - accuracy: 0.7403
# Epoch 34/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5372 - accuracy: 0.7397
# Epoch 35/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5371 - accuracy: 0.7400
# Epoch 36/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5381 - accuracy: 0.7386
# Epoch 37/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5371 - accuracy: 0.7398
# Epoch 38/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5371 - accuracy: 0.7397
# Epoch 39/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5373 - accuracy: 0.7392
# Epoch 40/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5367 - accuracy: 0.7400
# Epoch 41/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5359 - accuracy: 0.7409
# Epoch 42/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5365 - accuracy: 0.7407
# Epoch 43/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5364 - accuracy: 0.7404
# Epoch 44/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5361 - accuracy: 0.7404
# Epoch 45/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5362 - accuracy: 0.7408
# Epoch 46/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5360 - accuracy: 0.7404
# Epoch 47/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5361 - accuracy: 0.7402
# Epoch 48/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5354 - accuracy: 0.7414
# Epoch 49/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5354 - accuracy: 0.7410
# Epoch 50/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5353 - accuracy: 0.7406
# Epoch 51/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5354 - accuracy: 0.7400
# Epoch 52/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5361 - accuracy: 0.7409
# Epoch 53/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5355 - accuracy: 0.7401
# Epoch 54/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5350 - accuracy: 0.7407
# Epoch 55/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5355 - accuracy: 0.7421
# Epoch 56/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5348 - accuracy: 0.7421
# Epoch 57/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5352 - accuracy: 0.7409
# Epoch 58/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5351 - accuracy: 0.7413
# Epoch 59/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5344 - accuracy: 0.7423
# Epoch 60/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5345 - accuracy: 0.7410
# Epoch 61/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5345 - accuracy: 0.7412
# Epoch 62/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5344 - accuracy: 0.7410
# Epoch 63/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5346 - accuracy: 0.7420
# Epoch 64/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5346 - accuracy: 0.7410
# Epoch 65/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5343 - accuracy: 0.7414
# Epoch 66/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5341 - accuracy: 0.7421
# Epoch 67/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5347 - accuracy: 0.7421
# Epoch 68/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5338 - accuracy: 0.7424
# Epoch 69/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5340 - accuracy: 0.7416
# Epoch 70/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5340 - accuracy: 0.7423
# Epoch 71/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5340 - accuracy: 0.7421
# Epoch 72/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5341 - accuracy: 0.7423
# Epoch 73/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5331 - accuracy: 0.7428
# Epoch 74/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5334 - accuracy: 0.7423
# Epoch 75/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5336 - accuracy: 0.7425
# Epoch 76/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5335 - accuracy: 0.7414
# Epoch 77/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5330 - accuracy: 0.7410
# Epoch 78/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5333 - accuracy: 0.7422
# Epoch 79/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5332 - accuracy: 0.7424
# Epoch 80/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5338 - accuracy: 0.7418
# Epoch 81/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5331 - accuracy: 0.7418
# Epoch 82/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5332 - accuracy: 0.7416
# Epoch 83/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5327 - accuracy: 0.7426
# Epoch 84/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5331 - accuracy: 0.7414
# Epoch 85/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5335 - accuracy: 0.7410
# Epoch 86/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5325 - accuracy: 0.7418
# Epoch 87/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5328 - accuracy: 0.7425
# Epoch 88/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5329 - accuracy: 0.7428
# Epoch 89/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5328 - accuracy: 0.7421
# Epoch 90/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5325 - accuracy: 0.7423
# Epoch 91/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5324 - accuracy: 0.7425
# Epoch 92/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5328 - accuracy: 0.7424
# Epoch 93/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5323 - accuracy: 0.7420
# Epoch 94/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5327 - accuracy: 0.7424
# Epoch 95/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5321 - accuracy: 0.7423
# Epoch 96/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5324 - accuracy: 0.7428
# Epoch 97/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5323 - accuracy: 0.7413
# Epoch 98/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5322 - accuracy: 0.7427
# Epoch 99/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5323 - accuracy: 0.7420
# Epoch 100/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5321 - accuracy: 0.7420

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5732 - accuracy: 0.7209 - 442ms/epoch - 2ms/step
# Loss: 0.5731946229934692, Accuracy: 0.7209329605102539

# %%
history_df = pd.DataFrame(fit_model.history, index=range(1, len(fit_model.history["loss"])+1))
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharityOpt3.h5")
